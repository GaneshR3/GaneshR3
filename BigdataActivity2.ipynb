# %% [markdown]
# <a href="https://colab.research.google.com/github/GaneshR3/GaneshR3/blob/main/BigdataActivity2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *   Ganesh Rallabandi
# *  Id: 11814522

# %% [markdown]
# # Task 1 is Preparing a Structured Dataset :
# When data is organized into a table with rows and columns, it's called a structured dataset (e.g., CSV, Excel, SQL database).

# %% [markdown]
# # step 1: Structured Dataset
# I downloaded a UCI Machine Learning Repository dataset for this task;  i used bank marketng records.
# # Step 2: Loaded the Dataset in Python
# I used the pandas library to load and display the dataset:

# %%
pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo

# fetch dataset
bank_marketing = fetch_ucirepo(id=222)

# data (as pandas dataframes)
X = bank_marketing.data.features
y = bank_marketing.data.targets

# metadata
print(bank_marketing.metadata)

# variable information
print(bank_marketing.variables)
# Out:
# {'uci_id': 222, 'name': 'Bank Marketing', 'repository_url': 'https://archive.ics.uci.edu/dataset/222/bank+marketing', 'data_url': 'https://archive.ics.uci.edu/static/public/222/data.csv', 'abstract': 'The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).', 'area': 'Business', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 45211, 'num_features': 16, 'feature_types': ['Categorical', 'Integer'], 'demographics': ['Age', 'Occupation', 'Marital Status', 'Education Level'], 'target_col': ['y'], 'index_col': None, 'has_missing_values': 'yes', 'missing_values_symbol': 'NaN', 'year_of_dataset_creation': 2014, 'last_updated': 'Fri Aug 18 2023', 'dataset_doi': '10.24432/C5K306', 'creators': ['S. Moro', 'P. Rita', 'P. Cortez'], 'intro_paper': {'ID': 277, 'type': 'NATIVE', 'title': 'A data-driven approach to predict the
# ...

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("bank-full[1].csv")

# Display the first few rows
df.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  58;"management";"married";"tertiary";"no";2143...
# 1  44;"technician";"single";"secondary";"no";29;"...
# 2  33;"entrepreneur";"married";"secondary";"no";2...
# 3  47;"blue-collar";"married";"unknown";"no";1506...
# 4  33;"unknown";"single";"unknown";"no";1;"no";"n...
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %% [markdown]
# # Here above we can see the  visualize the dataset and  its structure.

# %% [markdown]
# # Step 3: Handling Missing Values
# I checked for missing values using the isnull() function:

# %%
import pandas as pd

# Load the dataset, specifying the delimiter as semicolon
df = pd.read_csv("bank-full[1].csv", delimiter=";")

# Display the first few rows
df.head()

# Check for missing values
print(df.isnull().sum())

# Fill missing values with the mean for numeric columns only
for col in df.select_dtypes(include=['number']): # loop through columns with numeric data type
    df[col].fillna(df[col].mean(), inplace=True)  # Fill missing values in that column with the column's mean
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
# <ipython-input-62-533cba56889a>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)  # Fill missing values in that column with the column's mean

# %% [markdown]
# above the steps handles the missing values by filling them with the mean for numerical columns.

# %% [markdown]
# # Step 4: Removing the Duplicate Entries
# To avoid redundancy in the dataset, I removed duplicates using:

# %%
df.drop_duplicates(inplace=True)

# %%
df.drop_duplicates()
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # Step 5: Converting Data Types
# It's possible that some columns have been typed incorrectly—for example, using strings rather than numbers. I changed the required columns to the proper data types:

# %%
df['balance'] = pd.to_numeric(df['balance'], errors='coerce')

# %%
(df.dtypes)
# Out:
# age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    object
# dtype: object

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv("bank-full[1].csv", delimiter=";") # Specify the delimiter

# Replace 'balance' with the actual column name you want to convert
column_to_convert = 'balance'
df[column_to_convert] = pd.to_numeric(df[column_to_convert], errors='coerce')

# Display the first few rows to verify the dataset
print("First few rows of the dataset:")
print(df.head())

# Display data types to confirm the conversion
print("\nColumn Data Types:")
print(df.dtypes)
# Out:
# First few rows of the dataset:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no
#
# Column Data Types:
# age           int64
# job          object
# ...

# %% [markdown]
# # Step 6: Feature Scaling
# To normalize or standardize numerical features, I used StandardScaler:

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load the dataset
df = pd.read_csv("bank-full[1].csv", delimiter=";")  # Specify the delimiter

# Display column names to identify numerical columns for scaling
print("Column Names:", df.columns)

# Replace 'column1' and 'column2' with actual numerical column names
numerical_columns = ['age', 'balance']  # Update with your desired columns

# Initialize StandardScaler
scaler = StandardScaler()

# Apply scaling to the selected numerical columns
df[numerical_columns] = scaler.fit_transform(df[numerical_columns])

# Display the first few rows after scaling
print("\nScaled Data:")
print(df.head())

# Check data types
print("\nData Types After Scaling:")
print(df.dtypes)
# Out:
# Column Names: Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')
#
# Scaled Data:
#         age           job  marital  education default   balance housing loan  \
# 0  1.606965    management  married   tertiary      no  0.256419     yes   no
# 1  0.288529    technician   single  secondary      no -0.437895     yes   no
# 2 -0.747384  entrepreneur  married  secondary      no -0.446762     yes  yes
# 3  0.571051   blue-collar  married    unknown      no  0.047205     yes   no
# 4 -0.747384       unknown   single    unknown      no -0.447091      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# ...

# %% [markdown]
# # Task 2: Preprocessing an Unstructured Dataset (Text)
# I opened and read a .txt file using Python’s built-in open() function:

# %%
# Step 1: Open and Read the Text File
with open("BigData.txt", "r", encoding="utf-8") as file:
    text = file.read()

# Print the content of the file
print(text)
# Out:
# This is an example of text preprocessing! It includes tokenization, stopword removal, and more.

# %% [markdown]
# # Step 2: Tokenization
# used the Natural Language toolkit(NLTK) to tokenize the text into smaller units words

# %%
import nltk
from nltk.tokenize import word_tokenize

# Download the 'punkt_tab' data for sentence tokenization
nltk.download('punkt_tab')

# Download the 'punkt' data for word tokenization
nltk.download('punkt')

tokens = word_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# ['This', 'is', 'an', 'example', 'of', 'text', 'preprocessing', '!', 'It', 'includes', 'tokenization', ',', 'stopword', 'removal', ',', 'and', 'more', '.']
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Step 3: Remove Stopwords and Punctuation
# Stopwords (common words like "the", "is", "and") and punctuation were removed to clean the text:

# %%
from nltk.corpus import stopwords
import string
nltk.download('stopwords')

stop_words = set(stopwords.words("english"))
cleaned_text = [word for word in tokens if word.lower() not in stop_words and word not in string.punctuation]

print(cleaned_text)
# Out:
# ['example', 'text', 'preprocessing', 'includes', 'tokenization', 'stopword', 'removal']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Report:Data Preprocessing
# #preprocessed structured and unstructured datasets' data
#  for this task. I have used the pandas library to load a dataset in CSV format into Python to handle structured data. Before handling any missing values, I made sure there was no data loss by replacing them with the column mean. To avoid redundancy, I then dropped any duplicate rows. Furthermore, I used type conversion to make sure that all columns were of the correct data type. StandardScaler was used to normalize numerical columns through feature scaling so that their scales were relative for any future analysis.
#
# For unstructured data, I worked with a text dataset. The first step was to load data from a.txt file. I then used the NLTK library to tokens the text in individual words (tokens).
# # After Tokenization,
#  I removed the stopword and punctuation to clean the text and made it more meaningful for analysis. Clean text was ready for further tasks such as emotion analysis, subject modeling, or classification.
#
# Through this process, I gained experience on hand with important preprosying tasks such as handling missing data, normalizing facilities and cleaning unnecessary text data. These steps are necessary to ensure that data is ready for analysis and machine learning.
#
# In this exercise, we read a text file, performed text preprocessing on an unstructured data set, and prepared it for analysis. The data set was a small text passage on text preprocessing methods and was held in BigData.txt. We checked the input data by loading and printing the content of the text file using Python's built-in open() function.
#
# # Steps Taken:
# Using the open("BigData.txt", "r", encoding="utf-8") function, we were able to read the text file successfully and captured its content in a variable. This process prepared the text for processing.
# Text Display: We displayed its contents so that the text was correct and free from errors in relation to files after it was loaded.
